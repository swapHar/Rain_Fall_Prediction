# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Read the data from data file

# %%
data = pd.read_csv('./data/austin_weather.csv')
data.head()
# Out:
#        Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0  21-12-13         74        60        45            67           49
# 1  22-12-13         56        48        39            43           36
# 2  23-12-13         58        45        32            31           27
# 3  24-12-13         61        46        31            36           28
# 4  25-12-13         58        50        41            44           40
#
#   DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  ...  \
# 0           43                  93                 75                 57  ...
# 1           28                  93                 68                 43  ...
# 2           23                  76                 52                 27  ...
# 3           21                  89                 56                 22  ...
# 4           36                  86                 71                 56  ...
#
# ...

# %% [markdown]
# Learn about our data

# %%
data.dtypes
# Out:
# Date                          object
# TempHighF                      int64
# TempAvgF                       int64
# TempLowF                       int64
# DewPointHighF                 object
# DewPointAvgF                  object
# DewPointLowF                  object
# HumidityHighPercent           object
# HumidityAvgPercent            object
# HumidityLowPercent            object
# SeaLevelPressureHighInches    object
# SeaLevelPressureAvgInches     object
# SeaLevelPressureLowInches     object
# VisibilityHighMiles           object
# VisibilityAvgMiles            object
# VisibilityLowMiles            object
# WindHighMPH                   object
# WindAvgMPH                    object
# WindGustMPH                   object
# PrecipitationSumInches        object
# Events                        object
# dtype: object

# %%
data.shape
# Out:
# (1319, 21)

# %%
# Drop few columns
data = data.drop(['Events', 'SeaLevelPressureHighInches', 'SeaLevelPressureLowInches'], axis=1)

# %%
print(data['DewPointHighF'].unique())
# Out:
# ['67' '43' '31' '36' '44' '39' '41' '49' '51' '37' '55' '54' '15' '29'
#  '60' '64' '58' '28' '42' '22' '38' '45' '19' '59' '62' '40' '17' '53'
#  '34' '48' '52' '61' '63' '33' '57' '65' '46' '32' '50' '27' '56' '47'
#  '68' '69' '66' '70' '73' '71' '76' '72' '75' '74' '-' '77' '23' '35' '30'
#  '79' '78' '80' '26' '18' '25' '13']

# %%
print(data['PrecipitationSumInches'].unique())
# Out:
# ['0.46' '0' 'T' '0.16' '0.1' '0.01' '0.06' '0.05' '0.02' '0.15' '0.11'
#  '0.08' '0.17' '0.74' '0.07' '0.2' '0.27' '1.34' '2.45' '0.94' '0.14'
#  '0.19' '1.56' '1.75' '0.55' '1.49' '0.24' '0.49' '0.31' '3.53' '1.52'
#  '0.09' '0.98' '0.22' '0.51' '0.68' '0.35' '3.66' '0.13' '0.21' '0.03'
#  '1.42' '0.3' '0.56' '1.51' '0.04' '0.33' '3.33' '0.59' '0.63' '0.76'
#  '2.07' '0.4' '0.26' '0.45' '2.17' '1.17' '0.43' '0.41' '0.57' '3.84'
#  '0.29' '0.23' '1.12' '0.36' '2.6' '1.41' '5.2' '0.67' '2.66' '1.09'
#  '0.93' '0.75' '1.05' '0.79' '4.79' '0.65' '4.93' '0.89' '0.53' '1.03'
#  '1.46' '0.25' '1.54' '1.32' '1.33' '2.18' '0.34' '1.19' '1.13' '0.58'
#  '0.54' '0.92' '0.77' '2.25' '0.52' '0.18' '1.07' '1.61' '1.06' '2.35'
#  '1.79' '1.22' '1.29' '0.37' '0.61' '1.57' '0.86' '0.66' '0.73' '0.71'
#  '0.12' '0.47' '1.39']

# %% [markdown]
# As we know from dataset information coloumn 'PrecipitationSumInches' contains 'T' as value at some instances.
# we need to convert all object datatypes to int or float datatype as we need all values in numerical format.
# Also values in Date column to date format.

# %%
data = data.replace('T','')
data = data.replace('-','')

# %%
data['DewPointHighF'] = pd.to_numeric(data['DewPointHighF'])
data['DewPointAvgF'] = pd.to_numeric(data['DewPointAvgF'])
data['DewPointLowF'] = pd.to_numeric(data['DewPointLowF'])
data['HumidityHighPercent'] = pd.to_numeric(data['HumidityHighPercent'])
data['HumidityAvgPercent'] = pd.to_numeric(data['HumidityAvgPercent'])
data['HumidityLowPercent'] = pd.to_numeric(data['HumidityLowPercent'])
data['SeaLevelPressureAvgInches'] = pd.to_numeric(data['SeaLevelPressureAvgInches'])
data['VisibilityHighMiles'] = pd.to_numeric(data['VisibilityHighMiles'])
data['VisibilityAvgMiles'] = pd.to_numeric(data['VisibilityAvgMiles'])
data['VisibilityLowMiles'] = pd.to_numeric(data['VisibilityLowMiles'])
data['WindHighMPH'] = pd.to_numeric(data['WindHighMPH'])
data['WindAvgMPH'] = pd.to_numeric(data['WindAvgMPH'])
data['WindGustMPH'] = pd.to_numeric(data['WindGustMPH'])
data['PrecipitationSumInches'] = pd.to_numeric(data['PrecipitationSumInches'])

# %%
data['Date'] = pd.to_datetime(data['Date'])
# Out:
# C:\Users\Swapnal\AppData\Local\Temp\ipykernel_26572\1453708669.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Date'] = pd.to_datetime(data['Date'])

# %%
data.isnull().sum()
# Out:
# Date                           0
# TempHighF                      0
# TempAvgF                       0
# TempLowF                       0
# DewPointHighF                  7
# DewPointAvgF                   7
# DewPointLowF                   7
# HumidityHighPercent            2
# HumidityAvgPercent             2
# HumidityLowPercent             2
# SeaLevelPressureAvgInches      3
# VisibilityHighMiles           12
# VisibilityAvgMiles            12
# VisibilityLowMiles            12
# WindHighMPH                    2
# WindAvgMPH                     2
# WindGustMPH                    4
# PrecipitationSumInches       124
# dtype: int64

# %% [markdown]
# Remove rows from data with missing values

# %%
data.dropna(inplace=True)

# %%
data.shape
# Out:
# (1183, 18)

# %%
data.describe()
# Out:
#                                 Date    TempHighF     TempAvgF     TempLowF  \
# count                           1183  1183.000000  1183.000000  1183.000000
# mean   2015-10-13 15:27:32.409129472    80.952663    70.528318    59.601014
# min              2013-12-21 00:00:00    32.000000    29.000000    19.000000
# 25%              2014-11-16 12:00:00    72.000000    61.000000    49.000000
# 50%              2015-10-07 00:00:00    83.000000    73.000000    62.000000
# 75%              2016-08-27 12:00:00    93.000000    83.000000    73.000000
# max              2017-12-07 00:00:00   107.000000    93.000000    81.000000
# std                              NaN    14.841901    14.142399    14.343669
#
#        DewPointHighF  DewPointAvgF  DewPointLowF  HumidityHighPercent  \
# count    1183.000000   1183.000000   1183.000000          1183.000000
# mean       61.310228     56.384615     50.678783            87.739645
# min        13.000000      8.000000      2.000000            37.000000
# ...

# %% [markdown]
# Lets split date in year and month for further analysis

# %%
data['Year'] = pd.DatetimeIndex(data['Date']).year
data['Month'] = pd.DatetimeIndex(data['Date']).month

# %%
data = data.drop('Date', axis=1)

# %%
print(data.columns)
# Out:
# Index(['TempHighF', 'TempAvgF', 'TempLowF', 'DewPointHighF', 'DewPointAvgF',
#        'DewPointLowF', 'HumidityHighPercent', 'HumidityAvgPercent',
#        'HumidityLowPercent', 'SeaLevelPressureAvgInches',
#        'VisibilityHighMiles', 'VisibilityAvgMiles', 'VisibilityLowMiles',
#        'WindHighMPH', 'WindAvgMPH', 'WindGustMPH', 'PrecipitationSumInches',
#        'Year', 'Month'],
#       dtype='object')

# %% [markdown]
# Lets explore the data

# %%
sns.histplot(data['PrecipitationSumInches'], bins=10, kde=True, stat="density")
# Out:
# <Axes: xlabel='PrecipitationSumInches', ylabel='Density'>

# %%
data.groupby('Month').mean()['PrecipitationSumInches'].plot(kind='bar')
# Out:
# <Axes: xlabel='Month'>

# %%
plt.figure(figsize=(6, 4))  
plt.scatter(data['PrecipitationSumInches'], data['TempHighF'], color='blue', alpha=0.5)  
plt.title('Precipitation vs. Temperature')  
plt.xlabel('Precipitation (inches)')  
plt.ylabel('Temperature (Fahrenheit)')  
plt.grid(True)  
plt.show()

# %%
num_col = [i for i in data.columns if data[i].dtype == 'int64' or data[i].dtype == 'float64']

c = 1
for i in num_col:
    plt.figure(figsize=(15,35))
    plt.subplot(21,1,c)
    sns.scatterplot(x=data[i],y=data['PrecipitationSumInches'])
    c = c+1

# %%
x = data.drop(columns=['PrecipitationSumInches','Year'])
y = data['PrecipitationSumInches']

# %%
#standardiz the features in DataFrame x using StandardScaler, 
# and then converts the standardized features back to a DataFrame.
sc = StandardScaler()
x_standard = sc.fit_transform(x)
x_standard = pd.DataFrame(x_standard,columns=x.columns)

# %%
# Split the dataset
x_train,x_test,y_train,y_test = train_test_split(x_standard, y, test_size=0.2, random_state=42)

# %% [markdown]
# Create the linear regression model and train it

# %%
rain_model = LinearRegression()
rain_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_predicted = rain_model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

print('Mean absolute error = ', mean_absolute_error(y_test, y_predicted))
print('Mean squared error = ', mean_squared_error(y_test, y_predicted))
print('R2 score = ', r2_score(y_test, y_predicted))
# Out:
# Mean absolute error =  0.17908789824269206
# Mean squared error =  0.10708314130128503
# R2 score =  0.43708666507779037

# %%
from sklearn.metrics import accuracy_score

y_test = np.array(y_test).astype(int)
y_predicted = np.array(y_predicted).astype(int)
accuracy = accuracy_score(y_test, y_predicted)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9535864978902954
